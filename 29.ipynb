# %%
import os
import pandas as pd
from langchain_community.document_loaders import DirectoryLoader
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_google_genai import ChatGoogleGenerativeAI

pdf_dir = "/Users/bhupathiraju_renisha/Desktop/trail/"
loader = DirectoryLoader(pdf_dir, glob="*.pdf", use_multithreading=True)
docs = loader.load()

if not docs:
    print("No documents loaded.")
    exit()

llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    api_key="AIzaSyDLsCYXLZPswtcr6dfJ4PgNLev-EWLBAcs",
)

class Resume(BaseModel):
    name: str = Field(default="", description="name from resume")
    phone: str = Field(default="", description="phone number from resume")
    email: str = Field(default="", description="email from resume")
    education: str = Field(default="", description="education from resume")
    projects: str = Field(default="", description="projects from resume")
    technical_skills: str = Field(default="", description="technical skills from resume")
    certifications: str = Field(default="", description="certifications from resume")
    languages: str = Field(default="", description="languages from resume")
    year_of_passing_university: str = Field(default="", description="year of passing university")
    GPA: str = Field(default="", description="GPA from resume")
    strength: str = Field(default="", description="strength from resume")
    weakness: str = Field(default="", description="weakness from resume")
    website: str = Field(default="", description="website from resume")
    reference: str = Field(default="", description="reference from resume")
    work_experience: str = Field(default="", description="work experience from resume")
    country: str = Field(default="", description="country from resume")
    occupation: str = Field(default="", description="occupation from resume")
    awards: str = Field(default="", description="awards from resume")
    activities: str = Field(default="", description="activities from resume")

parser = JsonOutputParser(pydantic_object=Resume)
prompt = PromptTemplate(
    template="Extract relevant details from the resume:\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

chain = prompt | llm | parser
answers = []

for i, doc in enumerate(docs):
    print(f"Processing Document {i+1}/{len(docs)}...")

    details = chain.invoke({"query": doc.page_content})
    cleaned_details = {key: ("" if value is None else value) for key, value in details.items()}
    
    print(f"Extracted Data: {cleaned_details}")
    answers.append(cleaned_details)

df = pd.DataFrame(answers).replace({None: ""})

if df.empty:
    print("No valid data extracted.")
else:
    print("DataFrame Preview:\n", df.head())

csv_file_path = "/Users/bhupathiraju_renisha/Documents/first/parquetfile/answers.csv"
if not df.empty:
    df.to_csv(csv_file_path, index=False, na_rep="")
    print(f"CSV saved successfully at: {csv_file_path}")
else:
    print("No data to save.")

if os.path.exists(csv_file_path):
    final_data = pd.read_csv(csv_file_path, dtype=str).fillna("")
    print("Final CSV Preview:\n", final_data.head())
    print("Columns:", final_data.columns)
# Out:
# /Users/bhupathiraju_renisha/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/bhupathiraju_renisha/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3550: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Processing Document 1/10...
# Extracted Data: {'name': 'BHUPATHIRAJU RENISHA', 'phone': '+91 8142678899', 'email': 'renishabhupathiraju@gmail.com', 'education': 'The State University of New York Artificial Intelligence - Diploma 2024\nSt Francis College For Women Post Graduate Diploma Business Analytics and Data Science 2024\nSt Francis College For Women Bachelor of Commerce International Business 2023\nPage Junior College Senior Secondary Education 2019\nBharatiya Vidya Bhavan’s Public School Secondary Education 2017', 'projects': 'Optimization of Machine Downtime -2024 Client-Leading Manufacturer of Fuel pumps\nA Study on Standard Charted Bank -2022', 'technical_skills': 'Python Power BI SQL Matplotlib Seaborn Tableau Tally Microsoft Word Microsoft Power Point Microsoft Excel', 'certifications': 'Business Analytics and Digital Media University of London 2020\nManagement Skills for International Business Indian School of Business 2020', 'year_of_passing_university': '2024', 'GPA': '', 'strength': '', 'weakness': '', 'website': '', 'reference': '', 'work_experience': '', 'country': 'India', 'occupation': '', 'awards': '', 'activities': ''}
# Processing Document 2/10...
# Extracted Data: {'name': 'DANIEL GALLEGO', 'phone': '', 'email': 'hello@reallygreatsite.com', 'education': 'UX Industrial Basics and General Application University of Engineering UX Cohort Major in Automotive Technology. Thesis on "Technological Advancements within the current Mechatronics Industry".\nAug 2016 - Oct 2019\nBachelor of Design in Process Engineering Engineering University\nMay 2014 - May 2016\nRelevant coursework in Structural Design and Project Management.', 'projects': '', 'technical_skills': 'Prototyping Tools User Research Information Architecture\nInteraction Design Visual Design Usability Heuristics\nAccessibility Responsive Design User Testing Tools', 'certifications': 'Professional Design Engineer (PDE) License, Project Management Tech (PMT)', 'languages': 'English, French, Mandarin', 'year_of_passing_university': '2019', 'GPA': '', 'strength': '', 'weakness': '', 'website': 'www.reallygreatsite.com', 'reference': '', 'work_experience': 'Instant Chartz App, Morcelle Program\nJan 2023 - Present\nLed development of an advanced automation system, achieving a 15% increase in operational efficiency. Streamlined manufacturing processes, reducing production costs by 10%. Implemented preventive maintenance strategies, resulting in a 20% decrease in equipment downtime.\n\nSystem UX Engineer, XarrowAI Industries\nFeb 2021 - Dec 2022\nDesigned and optimised a robotic control system, realizing a 12% performance improvement. Coordinated testing and validation, ensuring compliance with industry standards. Provided technical expertise, contributing to a 15% reduction in system failures.', 'country': '', 'occupation': 'UX DESIGNER', 'awards': 'Most Innovative Employer of the Year (2021), Overall Best Employee Division Two (2024), Onboarding Project Lead (2023)', 'activities': ''}
# Processing Document 3/10...
# Extracted Data: {'name': 'ISABEL MERCADO', 'phone': '+918877889988', 'email': 'hello@reallygreatsite.com', 'education': "Ginyard International Co. University Bachelor's Degree in Business Administration 2016 – 2020\nStudio Shodwe University Business Administration on Executive Assistance 2020 – 2022", 'projects': '', 'technical_skills': '', 'certifications': 'Executive Secretary and Business Administration Certification Advanced Executive Assistant and Office Manager Diploma Executive Office Professional Certificate Program', 'languages': '', 'year_of_passing_university': '2020', 'GPA': '', 'strength': 'Strong organizational and time- management skills Exceptional communication and interpersonal skills Ability to work independently and as part of a team Detail-oriented and able to handle multiple tasks simultaneously Experience in managing budgets and handling financial documents', 'weakness': '', 'website': '', 'reference': '', 'work_experience': "Executive Secretary Ingoude Company | 2018 - Present\nManage the schedules and calendars of the CEO and other senior executives Coordinate and schedule meetings and conferences with internal and external stakeholders Prepare and distribute meeting agendas, minutes, and other relevant materials Handle confidential information and documents with discretion and maintain their proper organization\nExecutive Assistant Wardiere Inc. | 2016 - 2018\nManaged calendars, scheduled appointments, and arranged meetings and conferences Prepared and distributed reports, presentations, and other materials Handled confidential documents and maintained their proper organization Coordinated travel arrangements and accommodations for executives and guests\nExecutive Secretary Intern Aldenaire & Partners | 2015 - 2016\nAssisted executive secretary in managing and coordinating schedules, meetings, and travel arrangements for senior executives Conducted research and prepared reports on various topics related to the company's operations and industry trends Provided administrative support, including answering phone calls, responding to emails, and preparing correspondence", 'country': '', 'occupation': 'Executive Secretary', 'awards': '', 'activities': ''}
# Processing Document 4/10...
# Extracted Data: {'name': 'RICHARD SANCHEZ', 'phone': '+91 9988778899', 'email': 'hello@reallygreatsite.com', 'education': '2029 - 2030 WARDIERE UNIVERSITY\nMaster of Business\nManagement\n2025 - 2029 WARDIERE UNIVERSITY\nBachelor of Business\nGPA: 3.8 / 4.0', 'projects': '', 'technical_skills': '', 'certifications': '', 'languages': 'English (Fluent) French (Fluent) German (Basics) Spanish (Intermediate)', 'year_of_passing_university': '2030', 'GPA': '3.8 / 4.0', 'strength': '', 'weakness': '', 'website': 'www.reallygreatsite.com', 'reference': 'Estelle Darcy\nHarper Richard\nWardiere Inc. / CTO\nWardiere Inc. / CEO\nPhone:\n123-456-7890\nPhone:\n123-456-7890\nEmail :\nhello@reallygreatsite.com\nEmail :\nhello@reallygreatsite.com', 'work_experience': "Borcelle Studio Marketing Manager & Specialist\n2030 - PRESENT\nDevelop and execute comprehensive marketing strategies and campaigns that align with the company's goals and objectives. Lead, mentor, and manage a high-performing marketing team, fostering a collaborative and results-driven work environment. Monitor brand consistency across marketing channels and materials.\nFauget Studio Marketing Manager & Specialist\n2025 - 2029\nCreate and manage the marketing budget, ensuring efficient allocation of resources and optimizing ROI. Oversee market research to identify emerging trends, customer needs, and competitor strategies. Monitor brand consistency across marketing channels and materials.\nStudio Shodwe Marketing Manager & Specialist\n2024 - 2025\nDevelop and maintain strong relationships with partners, agencies, and vendors to support marketing initiatives. Monitor and maintain brand consistency across all marketing channels and materials.", 'country': '', 'occupation': 'Marketing Manager', 'awards': '', 'activities': ''}
# Processing Document 5/10...
# Extracted Data: {'name': 'LAURICE MORETTI', 'phone': '+91 9966557788', 'email': 'hello@reallygreatsite.com', 'education': 'North State University | 2025-2027\nMaster of Systems Design and Management\nGPA: 3.5 Best Mentor Awardee Recognition for Extended Research Paper\n\nSouth City College | 2021-2025\nBachelor of Science in Computer Engineering\nGPA: 3.8 Editor-in-Chief, The SCC Tribune President, The IT Society', 'projects': '', 'technical_skills': '', 'certifications': 'Project Management | 2027 The Project Management Institute\nSystem Optimization | 2028 Scrum Learning Society\nRisk Management and Mitigation | 2028 Internal Auditors Team\nVendor Relations | 2030 North State University', 'languages': '', 'year_of_passing_university': '2027', 'GPA': '3.5, 3.8', 'strength': '', 'weakness': '', 'website': 'www.reallygreatsite.com', 'reference': '', 'work_experience': 'Senior Systems Designer | 2030-2035 The IT Company\nDesigned and implemented advanced system architectures, resulting in a 30% increase in operational efficiency Led a group of 10 engineers in developing scalable solutions, ensuring alignment with business objectives and regulatory requirements\n\nSystems Design Engineer | 2027-2030 Cyber Tech Company\nDeveloped robust system designs for clients in the healthcare, finance, and education industries Implemented best practices in system design and integration, improving system performance and reliability by 30%\n\nIT Project Analyst | 2025-2027 The Systems Design Inc.\nAssisted in the design and implementation of systems for small to mid-sized business clients Collaborated with junior and senior designers to develop system specifications and documentation', 'country': '', 'occupation': 'S Y S T E MS D E S I GN E R', 'awards': 'Best Mentor Awardee', 'activities': 'Editor-in-Chief, The SCC Tribune; President, The IT Society'}
# Processing Document 6/10...
# Extracted Data: {'name': 'JACQUELINE THOMPSON', 'phone': '+91 8899778899', 'email': 'hello@reallygreatsite.com', 'education': 'Master of Science in Mechanical Engineering University of Engineering and Technology\nSep 2019 - Oct 2020\nSpecialization in Advanced Manufacturing. Thesis on "Innovations in Sustainable Engineering Practices".\n\nBachelor of Science in Civil Engineering City College of Engineering\nAug 2015 - Aug 2019\nRelevant coursework in Structural Design and Project Management.', 'projects': 'Implemented cost-effective solutions, resulting in a 20% reduction in project expenses. Streamlined project workflows, enhancing overall efficiency by 25%. Led a team in successfully delivering a complex engineering project on time and within allocated budget.\n\nManaged project timelines, reducing delivery times by 30%. Spearheaded the adoption of cutting-edge engineering software, improving project accuracy by 15%. Collaborated with cross-functional teams, enhancing project success rates by 10%.\n\nCoordinated project tasks, ensuring adherence to engineering standards and regulations. Conducted comprehensive project analyses, identifying and rectifying discrepancies in engineering designs.', 'technical_skills': 'Project Management, Structural Analysis, Robotics and Automation, CAD', 'certifications': 'Professional Engineer (PE) License, Project Management Professional (PMP)', 'languages': 'English, Malay, German', 'year_of_passing_university': '2020', 'GPA': '', 'strength': '', 'weakness': '', 'website': 'www.reallygreatsite.com', 'reference': '', 'work_experience': 'Engineering Executive , Borcelle Technologies\nJan 2023 - Present\n\nProject Engineer, Salford & Co\nMar 2021 - Dec 2022\n\nGraduate Engineer, Arowwai Industries\nFeb 2020 - Jan 2021', 'country': '', 'occupation': 'Engineering Executive', 'awards': 'Received the "Engineering Excellence" Award for outstanding contributions to project innovation, Borcelle Technologies', 'activities': ''}
# Processing Document 7/10...
# Extracted Data: {'name': 'HARPER RUSSO', 'phone': '+919944667788', 'email': 'hello@reallygreatsite.com', 'education': 'Warner & Spencer Graduate Diploma in Business Administration\nWarner & Spencer Bachelor of Business (Honours)\nLarana, Inc. Graduate Certificate in Human Resource Management', 'projects': '', 'technical_skills': '', 'certifications': '', 'languages': '', 'year_of_passing_university': '', 'GPA': '', 'strength': 'P&L Management\nFinancial Reporting\nTeam Leadership\nBusiness Development\nNegotiation Skills\nCommunication\nStrategic Planning\nClient Relationship Management\nOperations Management', 'weakness': '', 'website': '@reallygreatsite', 'reference': 'References are available on request.', 'work_experience': 'Ginyard International Co. Operations Manager October 2019 - Present\nGiggling Platypus Co. Business Development Manager August 2017 - September 2019\nArowwai Industries Operations Manager February 2016 - July 2017\nAldenaire & Partners Sales and Client Relationship Manager January 2012 - February 2016', 'country': '', 'occupation': 'BUSINESS OPERATIONS MANAGER', 'awards': '', 'activities': ''}
# Processing Document 8/10...
# Extracted Data: {'name': 'SHAWN GARCIA', 'phone': '+91 9988774499', 'email': 'hello@reallygreatsite.com', 'education': '2014-2023\nBORCELLE UNIVERSITY\nSydney - Australia\nBachelor of Business Management\n\n2014-2018\nBORCELLE UNIVERSITY\nSydney - Australia\nMaster of Business Management', 'projects': '', 'technical_skills': 'Design Process\nProject Management\nData Visualization\nMachine Learning', 'certifications': '', 'languages': '', 'year_of_passing_university': '2023', 'GPA': '', 'strength': 'Management Skills\nCreativity\nDigital Marketing\nNegotiation\nCritical Thinking\nLeadership', 'weakness': '', 'website': '', 'reference': '', 'work_experience': '2020 - 2022\nSTUDIO SHOWDE\nCanberra - Australia\nLorem ipsum dolor sit amet, consectetur adipiscing elit.\nVestibulum sit amet quam rhoncus, egestas dui eget, malesuada\njusto. Ut aliquam augue.\n\n2016 - 2020\nELSETOWN COR.\nKota Baru - Singapore\nLorem ipsum dolor sit amet, consectetur adipiscing elit.\nVestibulum sit amet quam rhoncus, egestas dui eget, malesuada\njusto. Ut aliquam augue.\n\n2010 - 2015\nSTUDIO SHOWDE\nSydney - Australia\nLorem ipsum dolor sit amet, consectetur adipiscing elit.\nVestibulum sit amet quam rhoncus, egestas dui eget, malesuada\njusto. Ut aliquam augue.', 'country': 'Australia', 'occupation': '', 'awards': '', 'activities': ''}
# Processing Document 9/10...
# Extracted Data: {'name': 'BENJAMIN SHAH', 'phone': '+123-456-7890', 'email': 'hello@reallygreatsite.com', 'education': 'Ginyard University\nBachelor of Business Management\n2011 - 2014 3.8/4 GPA\nGinyard University\nMaster of Business Management\n2014 - 2016 3.8/4 GPA', 'projects': '', 'technical_skills': 'Digital Marketing', 'certifications': 'Digital Marketing Manager\nFauget Business Academy\n2016 - 2017', 'languages': '', 'year_of_passing_university': '2016', 'GPA': '3.8/4', 'strength': 'Management Skills\nDigital Marketing\nNegotiation\nCritical Thinking\nCommunication Skills', 'weakness': '', 'website': '', 'reference': '', 'work_experience': 'Business Consultant\nTimmerman Industries\n2018 - Present\nProperty Manager\nTimmerman Industries\n2016 - 2017', 'country': '', 'occupation': 'Business Consultant', 'awards': '', 'activities': ''}
# Processing Document 10/10...
# Extracted Data: {'name': 'OLIVIA WILSON', 'phone': '+91 9944332211', 'email': 'hello@reallygreatsite.com', 'education': '2029 - 2030 BORCELLE UNIVERSITY\nMaster of Business Management\n2025 - 2029 BORCELLE UNIVERSITY\nBachelor of Business Management\nGPA: 3.8 / 4.0', 'projects': '', 'technical_skills': '', 'certifications': '', 'languages': 'English: Fluent French: Fluent German: Basics Spanish: Intermediate', 'year_of_passing_university': '2030', 'GPA': '3.8 / 4.0', 'strength': '', 'weakness': '', 'website': 'www.reallygreatsite.com', 'reference': '', 'work_experience': '2030 - PRESENT Borcelle Studio Marketing Manager & Specialist\nLed the development and implementation of comprehensive marketing strategies that resulted in a 20% increase in brand visibility and a 15% growth in sales within the first year. launched and managed multiple cross-channel Successfully campaigns, including digital marketing, social media, and traditional advertising, resulting in improved customer acquisition and retention rates.\nFauget Studio Marketing Manager & Specialist\n2025 - 2029\nConducted market research to identify emerging trends and consumer preferences, providing valuable insights for product development and positioning. Oversaw the creation of engaging content for various platforms, collaborating with internal teams and external agencies to ensure brand consistency and relevance.\nStudio Shodwe Marketing Manager & Specialist\n2024 - 2025\nDeveloped and executed targeted marketing campaigns, resulting in a 25% increase in lead generation. Implemented SEO strategies that improved website traffic by 30%, enhancing online visibility and positioning the company. Collaborated with sales teams to create effective sales collateral, presentations, and promotional materials.', 'country': '', 'occupation': 'MARKETING MANAGER', 'awards': '', 'activities': ''}
# DataFrame Preview:
#                     name           phone                          email  \
# 0  BHUPATHIRAJU RENISHA  +91 8142678899  renishabhupathiraju@gmail.com
# 1        DANIEL GALLEGO                      hello@reallygreatsite.com
# 2        ISABEL MERCADO   +918877889988      hello@reallygreatsite.com
# 3       RICHARD SANCHEZ  +91 9988778899      hello@reallygreatsite.com
# 4       LAURICE MORETTI  +91 9966557788      hello@reallygreatsite.com
#
#                                            education  \
# 0  The State University of New York Artificial In...
# 1  UX Industrial Basics and General Application U...
# 2  Ginyard International Co. University Bachelor'...
# 3  2029 - 2030 WARDIERE UNIVERSITY\nMaster of Bus...
# 4  North State University | 2025-2027\nMaster of ...
#
#                                             projects  \
# 0  Optimization of Machine Downtime -2024 Client-...
# 1
# 2
# 3
# 4
#
#                                     technical_skills  \
# 0  Python Power BI SQL Matplotlib Seaborn Tableau...
# 1  Prototyping Tools User Research Information Ar...
# 2
# 3
# 4
#
#                                       certifications  \
# 0  Business Analytics and Digital Media Universit...
# 1  Professional Design Engineer (PDE) License, Pr...
# 2  Executive Secretary and Business Administratio...
# 3
# 4  Project Management | 2027 The Project Manageme...
#
#   year_of_passing_university        GPA  \
# 0                       2024
# 1                       2019
# 2                       2020
# 3                       2030  3.8 / 4.0
# 4                       2027   3.5, 3.8
#
#                                             strength weakness  \
# 0
# 1
# 2  Strong organizational and time- management ski...
# 3
# 4
#
#                    website                                          reference  \
# 0
# 1  www.reallygreatsite.com
# 2
# 3  www.reallygreatsite.com  Estelle Darcy\nHarper Richard\nWardiere Inc. /...
# 4  www.reallygreatsite.com
#
#                                      work_experience country  \
# 0                                                      India
# 1  Instant Chartz App, Morcelle Program\nJan 2023...
# 2  Executive Secretary Ingoude Company | 2018 - P...
# 3  Borcelle Studio Marketing Manager & Specialist...
# 4  Senior Systems Designer | 2030-2035 The IT Com...
#
#                     occupation  \
# 0
# 1                  UX DESIGNER
# 2          Executive Secretary
# 3            Marketing Manager
# 4  S Y S T E MS D E S I GN E R
#
#                                               awards  \
# 0
# 1  Most Innovative Employer of the Year (2021), O...
# 2
# 3
# 4                                Best Mentor Awardee
#
#                                           activities  \
# 0
# 1
# 2
# 3
# 4  Editor-in-Chief, The SCC Tribune; President, T...
#
#                                            languages
# 0
# 1                          English, French, Mandarin
# 2
# 3  English (Fluent) French (Fluent) German (Basic...
# 4
# CSV saved successfully at: /Users/bhupathiraju_renisha/Documents/first/parquetfile/answers.csv
# Final CSV Preview:
#                     name           phone                          email  \
# 0  BHUPATHIRAJU RENISHA  +91 8142678899  renishabhupathiraju@gmail.com
# 1        DANIEL GALLEGO                      hello@reallygreatsite.com
# 2        ISABEL MERCADO   +918877889988      hello@reallygreatsite.com
# 3       RICHARD SANCHEZ  +91 9988778899      hello@reallygreatsite.com
# 4       LAURICE MORETTI  +91 9966557788      hello@reallygreatsite.com
#
#                                            education  \
# 0  The State University of New York Artificial In...
# 1  UX Industrial Basics and General Application U...
# 2  Ginyard International Co. University Bachelor'...
# 3  2029 - 2030 WARDIERE UNIVERSITY\nMaster of Bus...
# 4  North State University | 2025-2027\nMaster of ...
#
#                                             projects  \
# 0  Optimization of Machine Downtime -2024 Client-...
# 1
# 2
# 3
# 4
#
#                                     technical_skills  \
# 0  Python Power BI SQL Matplotlib Seaborn Tableau...
# 1  Prototyping Tools User Research Information Ar...
# 2
# 3
# 4
#
#                                       certifications  \
# 0  Business Analytics and Digital Media Universit...
# 1  Professional Design Engineer (PDE) License, Pr...
# 2  Executive Secretary and Business Administratio...
# 3
# 4  Project Management | 2027 The Project Manageme...
#
#   year_of_passing_university        GPA  \
# 0                       2024
# 1                       2019
# 2                       2020
# 3                       2030  3.8 / 4.0
# 4                       2027   3.5, 3.8
#
#                                             strength weakness  \
# 0
# 1
# 2  Strong organizational and time- management ski...
# 3
# 4
#
#                    website                                          reference  \
# 0
# 1  www.reallygreatsite.com
# 2
# 3  www.reallygreatsite.com  Estelle Darcy\nHarper Richard\nWardiere Inc. /...
# 4  www.reallygreatsite.com
#
#                                      work_experience country  \
# 0                                                      India
# 1  Instant Chartz App, Morcelle Program\nJan 2023...
# 2  Executive Secretary Ingoude Company | 2018 - P...
# 3  Borcelle Studio Marketing Manager & Specialist...
# 4  Senior Systems Designer | 2030-2035 The IT Com...
#
#                     occupation  \
# 0
# 1                  UX DESIGNER
# 2          Executive Secretary
# 3            Marketing Manager
# 4  S Y S T E MS D E S I GN E R
#
#                                               awards  \
# 0
# 1  Most Innovative Employer of the Year (2021), O...
# 2
# 3
# 4                                Best Mentor Awardee
#
#                                           activities  \
# 0
# 1
# 2
# 3
# 4  Editor-in-Chief, The SCC Tribune; President, T...
#
#                                            languages
# 0
# 1                          English, French, Mandarin
# 2
# 3  English (Fluent) French (Fluent) German (Basic...
# 4
# Columns: Index(['name', 'phone', 'email', 'education', 'projects', 'technical_skills',
#        'certifications', 'year_of_passing_university', 'GPA', 'strength',
#        'weakness', 'website', 'reference', 'work_experience', 'country',
#        'occupation', 'awards', 'activities', 'languages'],
#       dtype='object')

# %%
file_path = "/Users/bhupathiraju_renisha/Documents/first/parquetfile/answers.csv"
data = pd.read_csv(file_path)
data = data.fillna('')

# %%
data
# Out:
#                    name           phone                          email  \
# 0  BHUPATHIRAJU RENISHA  +91 8142678899  renishabhupathiraju@gmail.com
# 1        DANIEL GALLEGO                      hello@reallygreatsite.com
# 2        ISABEL MERCADO   +918877889988      hello@reallygreatsite.com
# 3       RICHARD SANCHEZ  +91 9988778899      hello@reallygreatsite.com
# 4       LAURICE MORETTI  +91 9966557788      hello@reallygreatsite.com
# 5   JACQUELINE THOMPSON  +91 8899778899      hello@reallygreatsite.com
# 6          HARPER RUSSO   +919944667788      hello@reallygreatsite.com
# 7          SHAWN GARCIA  +91 9988774499      hello@reallygreatsite.com
# 8         BENJAMIN SHAH   +123-456-7890      hello@reallygreatsite.com
# 9         OLIVIA WILSON  +91 9944332211      hello@reallygreatsite.com
#
#                                            education  \
# 0  The State University of New York Artificial In...
# 1  UX Industrial Basics and General Application U...
# 2  Ginyard International Co. University Bachelor'...
# 3  2029 - 2030 WARDIERE UNIVERSITY\nMaster of Bus...
# 4  North State University | 2025-2027\nMaster of ...
# 5  Master of Science in Mechanical Engineering Un...
# 6  Warner & Spencer Graduate Diploma in Business ...
# 7  2014-2023\nBORCELLE UNIVERSITY\nSydney - Austr...
# 8  Ginyard University\nBachelor of Business Manag...
# 9  2029 - 2030 BORCELLE UNIVERSITY\nMaster of Bus...
#
#                                             projects  \
# 0  Optimization of Machine Downtime -2024 Client-...
# 1
# 2
# 3
# 4
# 5  Implemented cost-effective solutions, resultin...
# 6
# 7
# 8
# 9
#
#                                     technical_skills  \
# 0  Python Power BI SQL Matplotlib Seaborn Tableau...
# 1  Prototyping Tools User Research Information Ar...
# 2
# 3
# 4
# 5  Project Management, Structural Analysis, Robot...
# 6
# 7  Design Process\nProject Management\nData Visua...
# 8                                  Digital Marketing
# 9
#
#                                       certifications  \
# 0  Business Analytics and Digital Media Universit...
# 1  Professional Design Engineer (PDE) License, Pr...
# 2  Executive Secretary and Business Administratio...
# 3
# 4  Project Management | 2027 The Project Manageme...
# 5  Professional Engineer (PE) License, Project Ma...
# 6
# 7
# 8  Digital Marketing Manager\nFauget Business Aca...
# 9
#
#   year_of_passing_university        GPA  \
# 0                     2024.0
# 1                     2019.0
# 2                     2020.0
# 3                     2030.0  3.8 / 4.0
# 4                     2027.0   3.5, 3.8
# 5                     2020.0
# 6
# 7                     2023.0
# 8                     2016.0      3.8/4
# 9                     2030.0  3.8 / 4.0
#
#                                             strength weakness  \
# 0
# 1
# 2  Strong organizational and time- management ski...
# 3
# 4
# 5
# 6  P&L Management\nFinancial Reporting\nTeam Lead...
# 7  Management Skills\nCreativity\nDigital Marketi...
# 8  Management Skills\nDigital Marketing\nNegotiat...
# 9
#
#                    website                                          reference  \
# 0
# 1  www.reallygreatsite.com
# 2
# 3  www.reallygreatsite.com  Estelle Darcy\nHarper Richard\nWardiere Inc. /...
# 4  www.reallygreatsite.com
# 5  www.reallygreatsite.com
# 6         @reallygreatsite               References are available on request.
# 7
# 8
# 9  www.reallygreatsite.com
#
#                                      work_experience    country  \
# 0                                                         India
# 1  Instant Chartz App, Morcelle Program\nJan 2023...
# 2  Executive Secretary Ingoude Company | 2018 - P...
# 3  Borcelle Studio Marketing Manager & Specialist...
# 4  Senior Systems Designer | 2030-2035 The IT Com...
# 5  Engineering Executive , Borcelle Technologies\...
# 6  Ginyard International Co. Operations Manager O...
# 7  2020 - 2022\nSTUDIO SHOWDE\nCanberra - Austral...  Australia
# 8  Business Consultant\nTimmerman Industries\n201...
# 9  2030 - PRESENT Borcelle Studio Marketing Manag...
#
#                     occupation  \
# 0
# 1                  UX DESIGNER
# 2          Executive Secretary
# 3            Marketing Manager
# 4  S Y S T E MS D E S I GN E R
# 5        Engineering Executive
# 6  BUSINESS OPERATIONS MANAGER
# 7
# 8          Business Consultant
# 9            MARKETING MANAGER
#
#                                               awards  \
# 0
# 1  Most Innovative Employer of the Year (2021), O...
# 2
# 3
# 4                                Best Mentor Awardee
# 5  Received the "Engineering Excellence" Award fo...
# 6
# 7
# 8
# 9
#
#                                           activities  \
# 0
# 1
# 2
# 3
# 4  Editor-in-Chief, The SCC Tribune; President, T...
# 5
# 6
# 7
# 8
# 9
#
#                                            languages
# 0
# 1                          English, French, Mandarin
# 2
# 3  English (Fluent) French (Fluent) German (Basic...
# 4
# 5                             English, Malay, German
# 6
# 7
# 8
# 9  English: Fluent French: Fluent German: Basics ...
